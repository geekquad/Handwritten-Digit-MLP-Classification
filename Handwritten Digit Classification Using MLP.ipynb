# %% [markdown]
# Importing necesssary libraries:

# %%
import torch
import numpy as np
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

# %% [markdown]
# ## Loading and Visualizing the Data

# %%
num_workers = 0
batch_size = 20
valid_size = 0.2

transform = transforms.ToTensor()

train_data = datasets.MNIST(root='data', train=True,
                                   download=True, transform=transform)
test_data = datasets.MNIST(root='data', train=False,
                                  download=True, transform=transform)

num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
    num_workers=num_workers)

# %% [markdown]
# ## Visualizing a Batch Of Training Data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title(str(labels[idx].item()))

# %% [markdown]
# ## Viewing an Image in More Detail

# %%
img = np.squeeze(images[1])

fig = plt.figure(figsize = (12,12)) 
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')
width, height = img.shape
thresh = img.max()/2.5
for x in range(width):
    for y in range(height):
        val = round(img[x][y],2) if img[x][y] !=0 else 0
        ax.annotate(str(val), xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center',
                    color='white' if img[x][y]<thresh else 'black')

# %% [markdown]
# ## Defining the Network Architecture

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
  
        hidden_1 = 512
        hidden_2 = 512
       
        self.fc1 = nn.Linear(28 * 28, hidden_1)

        self.fc2 = nn.Linear(hidden_1, hidden_2)

        self.fc3 = nn.Linear(hidden_2, 10)
 
        self.dropout = nn.Dropout(0.2)

    def forward(self, x):
        
        x = x.view(-1, 28 * 28)
       
        x = F.relu(self.fc1(x))
        
        x = self.dropout(x)
       
        x = F.relu(self.fc2(x))
        
        x = self.dropout(x)
        
        x = self.fc3(x)
        return x

model = Net()
print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=10, bias=True)
#   (dropout): Dropout(p=0.2)
# )

# %%
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %% [markdown]
# ## Training the Network

# %%
epochs = 50

valid_loss_min = np.Inf

for epoch in range(epochs):
    train_loss = 0.0
    valid_loss = 0.0
    
    model.train()
    for data, target in train_loader:
        optimizer.zero_grad()
        output = model(data)
        
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()*data.size(0)
        
    model.eval()
    for data, target in valid_loader:
        output = model(data)
        loss = criterion(output, target)
        valid_loss += loss.item()*data.size(0)
        
    train_loss = train_loss/len(train_loader.sampler)
    valid_loss = valid_loss/len(valid_loader.sampler)
    
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(epoch+1, train_loss, valid_loss))
    
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format( valid_loss_min, valid_loss))
        torch.save(model.state_dict(), 'model.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.089078 	Validation Loss: 0.095229
# Validation loss decreased (inf --> 0.095229).  Saving model ...
# Epoch: 2 	Training Loss: 0.083261 	Validation Loss: 0.089377
# Validation loss decreased (0.095229 --> 0.089377).  Saving model ...
# Epoch: 3 	Training Loss: 0.078295 	Validation Loss: 0.085598
# Validation loss decreased (0.089377 --> 0.085598).  Saving model ...
# Epoch: 4 	Training Loss: 0.072538 	Validation Loss: 0.083376
# Validation loss decreased (0.085598 --> 0.083376).  Saving model ...
# Epoch: 5 	Training Loss: 0.066775 	Validation Loss: 0.081590
# Validation loss decreased (0.083376 --> 0.081590).  Saving model ...
# Epoch: 6 	Training Loss: 0.062374 	Validation Loss: 0.076432
# Validation loss decreased (0.081590 --> 0.076432).  Saving model ...
# Epoch: 7 	Training Loss: 0.058748 	Validation Loss: 0.075717
# Validation loss decreased (0.076432 --> 0.075717).  Saving model ...
# Epoch: 8 	Training Loss: 0.055687 	Validation Loss: 0.075745
# Epoch: 9 	Training Loss: 0.052414 	Validation Loss: 0.071935
# Validation loss decreased (0.075717 --> 0.071935).  Saving model ...
# Epoch: 10 	Training Loss: 0.048404 	Validation Loss: 0.071062
# Validation loss decreased (0.071935 --> 0.071062).  Saving model ...
# Epoch: 11 	Training Loss: 0.046749 	Validation Loss: 0.071887
# Epoch: 12 	Training Loss: 0.044299 	Validation Loss: 0.067538
# Validation loss decreased (0.071062 --> 0.067538).  Saving model ...
# Epoch: 13 	Training Loss: 0.041759 	Validation Loss: 0.069013
# Epoch: 14 	Training Loss: 0.039864 	Validation Loss: 0.067172
# Validation loss decreased (0.067538 --> 0.067172).  Saving model ...
# Epoch: 15 	Training Loss: 0.038025 	Validation Loss: 0.067154
# Validation loss decreased (0.067172 --> 0.067154).  Saving model ...
# Epoch: 16 	Training Loss: 0.034839 	Validation Loss: 0.065605
# Validation loss decreased (0.067154 --> 0.065605).  Saving model ...
# Epoch: 17 	Training Loss: 0.033831 	Validation Loss: 0.065291
# Validation loss decreased (0.065605 --> 0.065291).  Saving model ...
# Epoch: 18 	Training Loss: 0.031692 	Validation Loss: 0.065065
# Validation loss decreased (0.065291 --> 0.065065).  Saving model ...
# Epoch: 19 	Training Loss: 0.030424 	Validation Loss: 0.063153
# Validation loss decreased (0.065065 --> 0.063153).  Saving model ...
# Epoch: 20 	Training Loss: 0.029185 	Validation Loss: 0.062702
# Validation loss decreased (0.063153 --> 0.062702).  Saving model ...
# Epoch: 21 	Training Loss: 0.027906 	Validation Loss: 0.061937
# Validation loss decreased (0.062702 --> 0.061937).  Saving model ...
# Epoch: 22 	Training Loss: 0.027010 	Validation Loss: 0.062204
# Epoch: 23 	Training Loss: 0.025444 	Validation Loss: 0.061376
# Validation loss decreased (0.061937 --> 0.061376).  Saving model ...
# Epoch: 24 	Training Loss: 0.023680 	Validation Loss: 0.061612
# Epoch: 25 	Training Loss: 0.022739 	Validation Loss: 0.062608
# Epoch: 26 	Training Loss: 0.021576 	Validation Loss: 0.062248
# Epoch: 27 	Training Loss: 0.020827 	Validation Loss: 0.062362
# Epoch: 28 	Training Loss: 0.019347 	Validation Loss: 0.063171
# Epoch: 29 	Training Loss: 0.019205 	Validation Loss: 0.060908
# Validation loss decreased (0.061376 --> 0.060908).  Saving model ...
# Epoch: 30 	Training Loss: 0.018719 	Validation Loss: 0.060166
# Validation loss decreased (0.060908 --> 0.060166).  Saving model ...
# Epoch: 31 	Training Loss: 0.018040 	Validation Loss: 0.061638
# Epoch: 32 	Training Loss: 0.016939 	Validation Loss: 0.060277
# Epoch: 33 	Training Loss: 0.016167 	Validation Loss: 0.060745
# Epoch: 34 	Training Loss: 0.016347 	Validation Loss: 0.060920
# Epoch: 35 	Training Loss: 0.015947 	Validation Loss: 0.060572
# Epoch: 36 	Training Loss: 0.015508 	Validation Loss: 0.061600
# Epoch: 37 	Training Loss: 0.014563 	Validation Loss: 0.061980
# Epoch: 38 	Training Loss: 0.013508 	Validation Loss: 0.062071
# Epoch: 39 	Training Loss: 0.013959 	Validation Loss: 0.061349
# Epoch: 40 	Training Loss: 0.012041 	Validation Loss: 0.061065
# Epoch: 41 	Training Loss: 0.012941 	Validation Loss: 0.059749
# Validation loss decreased (0.060166 --> 0.059749).  Saving model ...
# Epoch: 42 	Training Loss: 0.012606 	Validation Loss: 0.060988
# Epoch: 43 	Training Loss: 0.011480 	Validation Loss: 0.060736
# Epoch: 44 	Training Loss: 0.011204 	Validation Loss: 0.061397
# Epoch: 45 	Training Loss: 0.010792 	Validation Loss: 0.059786
# Epoch: 46 	Training Loss: 0.010405 	Validation Loss: 0.061807
# Epoch: 47 	Training Loss: 0.009874 	Validation Loss: 0.060479
# Epoch: 48 	Training Loss: 0.009773 	Validation Loss: 0.061497
# Epoch: 49 	Training Loss: 0.009679 	Validation Loss: 0.062993
# Epoch: 50 	Training Loss: 0.009087 	Validation Loss: 0.061041

# %%
model.load_state_dict(torch.load('model.pt'))

# %% [markdown]
# ## Testing the Network:

# %%
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval()

for data, target in test_loader:
    output = model(data)
    loss = criterion(output, target)
    test_loss += loss.item()*data.size(0)
    _, pred = torch.max(output, 1)
    correct = np.squeeze(pred.eq(target.data.view_as(pred)))
    for i in range(len(target)):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

test_loss = test_loss/len(test_loader.sampler)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (str(i), 100 * class_correct[i] / class_total[i], np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % ( 100. * np.sum(class_correct) / np.sum(class_total), np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.058821
#
# Test Accuracy of     0: 98% (970/980)
# Test Accuracy of     1: 98% (1122/1135)
# Test Accuracy of     2: 97% (1011/1032)
# Test Accuracy of     3: 98% (993/1010)
# Test Accuracy of     4: 98% (965/982)
# Test Accuracy of     5: 97% (873/892)
# Test Accuracy of     6: 98% (945/958)
# Test Accuracy of     7: 97% (1000/1028)
# Test Accuracy of     8: 98% (959/974)
# Test Accuracy of     9: 97% (985/1009)
#
# Test Accuracy (Overall): 98% (9823/10000)

# %% [markdown]
# ## Visualizing Sample Test Results

# %%
dataiter = iter(test_loader)
images, labels = dataiter.next()
output = model(images)
_, preds = torch.max(output, 1)
images = images.numpy()

fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title("{} ({})".format(str(preds[idx].item()), str(labels[idx].item())), color=("green" if preds[idx]==labels[idx] else "red"))
