# %% [markdown]
# Importing necesssary libraries:

# %%
import torch
import numpy as np
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

# %% [markdown]
# ## Loading and Visualizing the Data

# %%
num_workers = 0
batch_size = 20
valid_size = 0.2

transform = transforms.ToTensor()

train_data = datasets.MNIST(root='data', train=True,
                                   download=True, transform=transform)
test_data = datasets.MNIST(root='data', train=False,
                                  download=True, transform=transform)

num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
    num_workers=num_workers)

# %% [markdown]
# ## Visualizing a Batch Of Training Data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title(str(labels[idx].item()))

# %% [markdown]
# ## Viewing an Image in More Detail

# %%
img = np.squeeze(images[1])

fig = plt.figure(figsize = (12,12)) 
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')
width, height = img.shape
thresh = img.max()/2.5
for x in range(width):
    for y in range(height):
        val = round(img[x][y],2) if img[x][y] !=0 else 0
        ax.annotate(str(val), xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center',
                    color='white' if img[x][y]<thresh else 'black')

# %% [markdown]
# ## Defining the Network Architecture

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
  
        hidden_1 = 512
        hidden_2 = 512
       
        self.fc1 = nn.Linear(28 * 28, hidden_1)

        self.fc2 = nn.Linear(hidden_1, hidden_2)

        self.fc3 = nn.Linear(hidden_2, 10)
 
        self.dropout = nn.Dropout(0.2)

    def forward(self, x):
        
        x = x.view(-1, 28 * 28)
       
        x = F.relu(self.fc1(x))
        
        x = self.dropout(x)
       
        x = F.relu(self.fc2(x))
        
        x = self.dropout(x)
        
        x = self.fc3(x)
        return x

model = Net()
print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=10, bias=True)
#   (dropout): Dropout(p=0.2)
# )

# %%
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %% [markdown]
# ## Training the Network

# %%
epochs = 50

valid_loss_min = np.Inf

for epoch in range(epochs):
    train_loss = 0.0
    valid_loss = 0.0
    
    model.train()
    for data, target in train_loader:
        optimizer.zero_grad()
        output = model(data)
        
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()*data.size(0)
        
    model.eval()
    for data, target in valid_loader:
        output = model(data)
        loss = criterion(output, target)
        valid_loss += loss.item()*data.size(0)
        
    train_loss = train_loss/len(train_loader.sampler)
    valid_loss = valid_loss/len(valid_loader.sampler)
    
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(epoch+1, train_loss, valid_loss))
    
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format( valid_loss_min, valid_loss))
        torch.save(model.state_dict(), 'model.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.961559 	Validation Loss: 0.372251
# Validation loss decreased (inf --> 0.372251).  Saving model ...
# Epoch: 2 	Training Loss: 0.356440 	Validation Loss: 0.281804
# Validation loss decreased (0.372251 --> 0.281804).  Saving model ...
# Epoch: 3 	Training Loss: 0.281234 	Validation Loss: 0.230653
# Validation loss decreased (0.281804 --> 0.230653).  Saving model ...
# Epoch: 4 	Training Loss: 0.232729 	Validation Loss: 0.194553
# Validation loss decreased (0.230653 --> 0.194553).  Saving model ...
# Epoch: 5 	Training Loss: 0.195931 	Validation Loss: 0.169259
# Validation loss decreased (0.194553 --> 0.169259).  Saving model ...
# Epoch: 6 	Training Loss: 0.169501 	Validation Loss: 0.150909
# Validation loss decreased (0.169259 --> 0.150909).  Saving model ...
# Epoch: 7 	Training Loss: 0.152638 	Validation Loss: 0.135536
# Validation loss decreased (0.150909 --> 0.135536).  Saving model ...
# Epoch: 8 	Training Loss: 0.135084 	Validation Loss: 0.122643
# Validation loss decreased (0.135536 --> 0.122643).  Saving model ...
# Epoch: 9 	Training Loss: 0.122450 	Validation Loss: 0.113269
# Validation loss decreased (0.122643 --> 0.113269).  Saving model ...
# Epoch: 10 	Training Loss: 0.111823 	Validation Loss: 0.106217
# Validation loss decreased (0.113269 --> 0.106217).  Saving model ...
# Epoch: 11 	Training Loss: 0.102322 	Validation Loss: 0.099615
# Validation loss decreased (0.106217 --> 0.099615).  Saving model ...
# Epoch: 12 	Training Loss: 0.094040 	Validation Loss: 0.093670
# Validation loss decreased (0.099615 --> 0.093670).  Saving model ...
# Epoch: 13 	Training Loss: 0.086280 	Validation Loss: 0.088979
# Validation loss decreased (0.093670 --> 0.088979).  Saving model ...
# Epoch: 14 	Training Loss: 0.081286 	Validation Loss: 0.083162
# Validation loss decreased (0.088979 --> 0.083162).  Saving model ...
# Epoch: 15 	Training Loss: 0.074350 	Validation Loss: 0.080970
# Validation loss decreased (0.083162 --> 0.080970).  Saving model ...
# Epoch: 16 	Training Loss: 0.069953 	Validation Loss: 0.080812
# Validation loss decreased (0.080970 --> 0.080812).  Saving model ...
# Epoch: 17 	Training Loss: 0.065324 	Validation Loss: 0.078205
# Validation loss decreased (0.080812 --> 0.078205).  Saving model ...
# Epoch: 18 	Training Loss: 0.061494 	Validation Loss: 0.072900
# Validation loss decreased (0.078205 --> 0.072900).  Saving model ...
# Epoch: 19 	Training Loss: 0.057886 	Validation Loss: 0.072547
# Validation loss decreased (0.072900 --> 0.072547).  Saving model ...
# Epoch: 20 	Training Loss: 0.053597 	Validation Loss: 0.070473
# Validation loss decreased (0.072547 --> 0.070473).  Saving model ...
# Epoch: 21 	Training Loss: 0.052843 	Validation Loss: 0.068514
# Validation loss decreased (0.070473 --> 0.068514).  Saving model ...
# Epoch: 22 	Training Loss: 0.047200 	Validation Loss: 0.065217
# Validation loss decreased (0.068514 --> 0.065217).  Saving model ...
# Epoch: 23 	Training Loss: 0.045994 	Validation Loss: 0.068661
# Epoch: 24 	Training Loss: 0.043517 	Validation Loss: 0.064453
# Validation loss decreased (0.065217 --> 0.064453).  Saving model ...
# Epoch: 25 	Training Loss: 0.040967 	Validation Loss: 0.063244
# Validation loss decreased (0.064453 --> 0.063244).  Saving model ...
# Epoch: 26 	Training Loss: 0.039647 	Validation Loss: 0.064516
# Epoch: 27 	Training Loss: 0.036624 	Validation Loss: 0.061493
# Validation loss decreased (0.063244 --> 0.061493).  Saving model ...
# Epoch: 28 	Training Loss: 0.033631 	Validation Loss: 0.061458
# Validation loss decreased (0.061493 --> 0.061458).  Saving model ...
# Epoch: 29 	Training Loss: 0.032182 	Validation Loss: 0.059829
# Validation loss decreased (0.061458 --> 0.059829).  Saving model ...
# Epoch: 30 	Training Loss: 0.031282 	Validation Loss: 0.061738
# Epoch: 31 	Training Loss: 0.029550 	Validation Loss: 0.060152
# Epoch: 32 	Training Loss: 0.027907 	Validation Loss: 0.059775
# Validation loss decreased (0.059829 --> 0.059775).  Saving model ...
# Epoch: 33 	Training Loss: 0.027586 	Validation Loss: 0.058605
# Validation loss decreased (0.059775 --> 0.058605).  Saving model ...
# Epoch: 34 	Training Loss: 0.025548 	Validation Loss: 0.059910
# Epoch: 35 	Training Loss: 0.023984 	Validation Loss: 0.060181
# Epoch: 36 	Training Loss: 0.022933 	Validation Loss: 0.058812
# Epoch: 37 	Training Loss: 0.022644 	Validation Loss: 0.059219
# Epoch: 38 	Training Loss: 0.022052 	Validation Loss: 0.058445
# Validation loss decreased (0.058605 --> 0.058445).  Saving model ...
# Epoch: 39 	Training Loss: 0.019648 	Validation Loss: 0.057973
# Validation loss decreased (0.058445 --> 0.057973).  Saving model ...
# Epoch: 40 	Training Loss: 0.019587 	Validation Loss: 0.060259
# Epoch: 41 	Training Loss: 0.018478 	Validation Loss: 0.059056
# Epoch: 42 	Training Loss: 0.018044 	Validation Loss: 0.058735
# Epoch: 43 	Training Loss: 0.017065 	Validation Loss: 0.060198
# Epoch: 44 	Training Loss: 0.016100 	Validation Loss: 0.060329
# Epoch: 45 	Training Loss: 0.016055 	Validation Loss: 0.059811
# Epoch: 46 	Training Loss: 0.015577 	Validation Loss: 0.057674
# Validation loss decreased (0.057973 --> 0.057674).  Saving model ...
# Epoch: 47 	Training Loss: 0.014821 	Validation Loss: 0.057626
# Validation loss decreased (0.057674 --> 0.057626).  Saving model ...
# Epoch: 48 	Training Loss: 0.014959 	Validation Loss: 0.059040
# Epoch: 49 	Training Loss: 0.013465 	Validation Loss: 0.056348
# Validation loss decreased (0.057626 --> 0.056348).  Saving model ...
# Epoch: 50 	Training Loss: 0.013167 	Validation Loss: 0.058098

# %%
model.load_state_dict(torch.load('model.pt'))

# %% [markdown]
# ## Testing the Network:

# %%
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval()

for data, target in test_loader:
    output = model(data)
    loss = criterion(output, target)
    test_loss += loss.item()*data.size(0)
    _, pred = torch.max(output, 1)
    correct = np.squeeze(pred.eq(target.data.view_as(pred)))
    for i in range(len(target)):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

test_loss = test_loss/len(test_loader.sampler)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (str(i), 100 * class_correct[i] / class_total[i], np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % ( 100. * np.sum(class_correct) / np.sum(class_total), np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.057748
#
# Test Accuracy of     0: 99% (971/980)
# Test Accuracy of     1: 99% (1128/1135)
# Test Accuracy of     2: 98% (1013/1032)
# Test Accuracy of     3: 98% (994/1010)
# Test Accuracy of     4: 98% (965/982)
# Test Accuracy of     5: 98% (876/892)
# Test Accuracy of     6: 97% (938/958)
# Test Accuracy of     7: 97% (1002/1028)
# Test Accuracy of     8: 97% (946/974)
# Test Accuracy of     9: 97% (984/1009)
#
# Test Accuracy (Overall): 98% (9817/10000)
